# %%
import pandas as pd
import numpy as np
import sklearn
import xgboost
import shap
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("sklearn:", sklearn.__version__)
print("xgboost:", xgboost.__version__)
print("✅ Dissertation environment working correctly")
# Out:
# pandas: 3.0.1
# numpy: 2.4.2
# sklearn: 1.8.0
# xgboost: 3.2.0
# ✅ Dissertation environment working correctly

# %%
from interpret.glassbox import ExplainableBoostingClassifier
print("interpret ready")

import sklearn, numpy, xgboost, shap
print("sklearn :", sklearn.__version__)
print("numpy   :", numpy.__version__)
print("xgboost :", xgboost.__version__)
print("shap    :", shap.__version__)
# Out:
# interpret ready
# sklearn : 1.8.0
# numpy   : 2.4.2
# xgboost : 3.2.0
# shap    : 0.50.0
